# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Input, Dense, Concatenate
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.losses import MeanSquaredError

# Instantiate the Mean Squared Error loss
mse = MeanSquaredError()
from tensorflow.keras.metrics import MeanSquaredError
import matplotlib.pyplot as plt

def create_multimodal_autoencoder(packet_input_size, temporal_input_size, protocol_input_size):
    # Define input layers for each modality
    packet_input = Input(shape=(packet_input_size,), name="packet_input")
    temporal_input = Input(shape=(temporal_input_size,), name="temporal_input")
    protocol_input = Input(shape=(protocol_input_size,), name="protocol_input")

    # Packet encoder
    packet_encoded = Dense(64, activation='relu')(packet_input)
    packet_encoded = Dense(32, activation='relu')(packet_encoded)

    # Temporal encoder
    temporal_encoded = Dense(64, activation='relu')(temporal_input)
    temporal_encoded = Dense(32, activation='relu')(temporal_encoded)

    # Protocol encoder
    protocol_encoded = Dense(16, activation='relu')(protocol_input)
    protocol_encoded = Dense(8, activation='relu')(protocol_encoded)

    # Combine the encoded representations
    combined = Concatenate()([packet_encoded, temporal_encoded, protocol_encoded])

    # Shared latent space
    latent = Dense(32, activation='relu', name="latent_space")(combined)

    # Decoders for each modality
    # Packet decoder
    packet_decoded = Dense(32, activation='relu')(latent)
    packet_decoded = Dense(64, activation='relu')(packet_decoded)
    packet_decoded = Dense(packet_input_size, activation='linear', name="packet_output")(packet_decoded)

    # Temporal decoder
    temporal_decoded = Dense(32, activation='relu')(latent)
    temporal_decoded = Dense(64, activation='relu')(temporal_decoded)
    temporal_decoded = Dense(temporal_input_size, activation='linear', name="temporal_output")(temporal_decoded)

    # Protocol decoder
    protocol_decoded = Dense(8, activation='relu')(latent)
    protocol_decoded = Dense(16, activation='relu')(protocol_decoded)
    protocol_decoded = Dense(protocol_input_size, activation='linear', name="protocol_output")(protocol_decoded)

    # Build the autoencoder model
    autoencoder = Model(
        inputs=[packet_input, temporal_input, protocol_input], 
        outputs=[packet_decoded, temporal_decoded, protocol_decoded]
    )

    # Compile the model
    autoencoder.compile(
        optimizer='adam', 
        loss={
            'packet_output': 'mean_squared_error', 
            'temporal_output': 'mean_squared_error', 
            'protocol_output': 'mean_squared_error'
        }
    )

    return autoencoder

def train_multimodal_autoencoder(data_path):
    # Load the dataset
    data = pd.read_csv(data_path)

    # Define feature groups
    packet_features = ['ul_total_num_pkts', 'ul_total_num_bytes', 'ul_min_pkt_size', 
                   'ul_max_pkt_size', 'ul_mean_pkt_size', 'ul_std_pkt_size', 
                   'dl_total_num_pkts', 'dl_total_num_bytes', 'dl_min_pkt_size', 
                   'dl_max_pkt_size', 'dl_mean_pkt_size', 'dl_std_pkt_size']

   
    temporal_features = ['ul_min_iat', 'ul_max_iat', 'ul_mean_iat', 'ul_std_iat', 'ul_dur',
                     'dl_min_iat', 'dl_max_iat', 'dl_mean_iat', 'dl_std_iat', 'dl_dur']

    protocol_features = ['protocal', 'port_A', 'port_B','ip_A', 'ip_B']

    # Separate features
    X_packet = data[packet_features]
    X_temporal = data[temporal_features]
    X_protocol = data[protocol_features]

    # Normalize features
    scaler_packet = StandardScaler()
    scaler_temporal = StandardScaler()
    scaler_protocol = StandardScaler()

    X_packet_scaled = scaler_packet.fit_transform(X_packet)
    X_temporal_scaled = scaler_temporal.fit_transform(X_temporal)
    X_protocol_scaled = scaler_protocol.fit_transform(X_protocol)

    # Create and train the autoencoder
    autoencoder = create_multimodal_autoencoder(
        len(packet_features), 
        len(temporal_features), 
        len(protocol_features)
    )

    # Train the autoencoder
    history = autoencoder.fit(
        [X_packet_scaled, X_temporal_scaled, X_protocol_scaled], 
        [X_packet_scaled, X_temporal_scaled, X_protocol_scaled], 
        epochs=50, 
        batch_size=32, 
        validation_split=0.2,
        verbose=1
    )

    # Save the model and scalers
    autoencoder.save("multimodal_network_autoencoder.h5", save_format='h5')
    import joblib
    joblib.dump(scaler_packet, 'packet_scaler.pkl')
    joblib.dump(scaler_temporal, 'temporal_scaler.pkl')
    joblib.dump(scaler_protocol, 'protocol_scaler.pkl')

    # Plot the training and validation loss
    plt.figure(figsize=(10, 6))
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Multimodal Autoencoder Training and Validation Loss')
    plt.legend()
    plt.tight_layout()
    plt.show()
    plt.close()

    print("Model training completed. Model and scalers saved.")

# Example usage
if __name__ == "__main__":
    train_multimodal_autoencoder('Processed_random.csv')
# Out:
# Epoch 1/50
# C:\Users\Lenovo\AppData\Roaming\Python\Python311\site-packages\keras\src\models\functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['packet_input', 'temporal_input', 'protocol_input']. Received: the structure of inputs=('*', '*', '*')
#   warnings.warn(
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 2.0413 - packet_output_loss: 0.7661 - protocol_output_loss: 0.8433 - temporal_output_loss: 0.4319 - val_loss: 0.5931 - val_packet_output_loss: 0.0697 - val_protocol_output_loss: 0.4904 - val_temporal_output_loss: 0.0345
# Epoch 2/50
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4667 - packet_output_loss: 0.2057 - protocol_output_loss: 0.2351 - temporal_output_loss: 0.0259 - val_loss: 0.2096 - val_packet_output_loss: 0.0344 - val_protocol_output_loss: 0.1572 - val_temporal_output_loss: 0.0184
# Epoch 3/50
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1196 - packet_output_loss: 0.0405 - protocol_output_loss: 0.0608 - temporal_output_loss: 0.0183 - val_loss: 0.1313 - val_packet_output_loss: 0.0205 - val_protocol_output_loss: 0.0987 - val_temporal_output_loss: 0.0126
# Epoch 4/50
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0561 - packet_output_loss: 0.0247 - protocol_output_loss: 0.0222 - temporal_output_loss: 0.0093 - val_loss: 0.1141 - val_packet_output_loss: 0.0194 - val_protocol_output_loss: 0.0869 - val_temporal_output_loss: 0.0084
# Epoch 5/50
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0440 - packet_output_loss: 0.0217 - protocol_output_loss: 0.0151 - temporal_output_loss: 0.0072 - val_loss: 0.1001 - val_packet_output_loss: 0.0126 - val_protocol_output_loss: 0.0815 - val_temporal_output_loss: 0.0065
# Epoch 6/50
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0522 - packet_output_loss: 0.0289 - protocol_output_loss: 0.0131 - temporal_output_loss: 0.0102 - val_loss: 0.0896 - val_packet_output_loss: 0.0088 - val_protocol_output_loss: 0.0753 - val_temporal_output_loss: 0.0059
# Epoch 7/50
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0265 - packet_output_loss: 0.0110 - protocol_output_loss: 0.0103 - temporal_output_loss: 0.0052 - val_loss: 0.1002 - val_packet_output_loss: 0.0218 - val_protocol_output_loss: 0.0729 - val_temporal_output_loss: 0.0060
# Epoch 8/50
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0467 - packet_output_loss: 0.0321 - protocol_output_loss: 0.0091 - temporal_output_loss: 0.0055 - val_loss: 0.0859 - val_packet_output_loss: 0.0078 - val_protocol_output_loss: 0.0738 - val_temporal_output_loss: 0.0047
# Epoch 9/50
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0243 - packet_output_loss: 0.0128 - protocol_output_loss: 0.0072 - temporal_output_loss: 0.0043 - val_loss: 0.0794 - val_packet_output_loss: 0.0064 - val_protocol_output_loss: 0.0692 - val_temporal_output_loss: 0.0042
# Epoch 10/50
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0270 - packet_output_loss: 0.0120 - protocol_output_loss: 0.0099 - temporal_output_loss: 0.0051 - val_loss: 0.0789 - val_packet_output_loss: 0.0062 - val_protocol_output_loss: 0.0692 - val_temporal_output_loss: 0.0039
# Epoch 11/50
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0249 - packet_output_loss: 0.0140 - protocol_output_loss: 0.0057 - temporal_output_loss: 0.0052 - val_loss: 0.0816 - val_packet_output_loss: 0.0093 - val_protocol_output_loss: 0.0681 - val_temporal_output_loss: 0.0046
# Epoch 12/50
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1020 - packet_output_loss: 0.0896 - protocol_output_loss: 0.0073 - temporal_output_loss: 0.0052 - val_loss: 0.0866 - val_packet_output_loss: 0.0091 - val_protocol_output_loss: 0.0666 - val_temporal_output_loss: 0.0113
# Epoch 13/50
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0224 - packet_output_loss: 0.0074 - protocol_output_loss: 0.0045 - temporal_output_loss: 0.0105 - val_loss: 0.0754 - val_packet_output_loss: 0.0057 - val_protocol_output_loss: 0.0662 - val_temporal_output_loss: 0.0038
# Epoch 14/50
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0200 - packet_output_loss: 0.0118 - protocol_output_loss: 0.0045 - temporal_output_loss: 0.0038 - val_loss: 0.0748 - val_packet_output_loss: 0.0054 - val_protocol_output_loss: 0.0666 - val_temporal_output_loss: 0.0032
# Epoch 15/50
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0132 - packet_output_loss: 0.0058 - protocol_output_loss: 0.0044 - temporal_output_loss: 0.0031 - val_loss: 0.0752 - val_packet_output_loss: 0.0043 - val_protocol_output_loss: 0.0677 - val_temporal_output_loss: 0.0035
# Epoch 16/50
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0122 - packet_output_loss: 0.0052 - protocol_output_loss: 0.0036 - temporal_output_loss: 0.0034 - val_loss: 0.0755 - val_packet_output_loss: 0.0057 - val_protocol_output_loss: 0.0663 - val_temporal_output_loss: 0.0039
# Epoch 17/50
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0122 - packet_output_loss: 0.0054 - protocol_output_loss: 0.0031 - temporal_output_loss: 0.0037 - val_loss: 0.0867 - val_packet_output_loss: 0.0070 - val_protocol_output_loss: 0.0695 - val_temporal_output_loss: 0.0106
# Epoch 18/50
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0168 - packet_output_loss: 0.0050 - protocol_output_loss: 0.0045 - temporal_output_loss: 0.0073 - val_loss: 0.0742 - val_packet_output_loss: 0.0044 - val_protocol_output_loss: 0.0667 - val_temporal_output_loss: 0.0036
# Epoch 19/50
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0129 - packet_output_loss: 0.0056 - protocol_output_loss: 0.0042 - temporal_output_loss: 0.0031 - val_loss: 0.0766 - val_packet_output_loss: 0.0041 - val_protocol_output_loss: 0.0678 - val_temporal_output_loss: 0.0051
# Epoch 20/50
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0205 - packet_output_loss: 0.0123 - protocol_output_loss: 0.0035 - temporal_output_loss: 0.0046 - val_loss: 0.0732 - val_packet_output_loss: 0.0047 - val_protocol_output_loss: 0.0653 - val_temporal_output_loss: 0.0035
# Epoch 21/50
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0107 - packet_output_loss: 0.0054 - protocol_output_loss: 0.0026 - temporal_output_loss: 0.0027 - val_loss: 0.0740 - val_packet_output_loss: 0.0057 - val_protocol_output_loss: 0.0649 - val_temporal_output_loss: 0.0039
# Epoch 22/50
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0127 - packet_output_loss: 0.0058 - protocol_output_loss: 0.0032 - temporal_output_loss: 0.0037 - val_loss: 0.0794 - val_packet_output_loss: 0.0107 - val_protocol_output_loss: 0.0648 - val_temporal_output_loss: 0.0042
# Epoch 23/50
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0378 - packet_output_loss: 0.0315 - protocol_output_loss: 0.0030 - temporal_output_loss: 0.0033 - val_loss: 0.0700 - val_packet_output_loss: 0.0031 - val_protocol_output_loss: 0.0651 - val_temporal_output_loss: 0.0022
# Epoch 24/50
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0259 - packet_output_loss: 0.0205 - protocol_output_loss: 0.0026 - temporal_output_loss: 0.0027 - val_loss: 0.0521 - val_packet_output_loss: 0.0037 - val_protocol_output_loss: 0.0463 - val_temporal_output_loss: 0.0024
# Epoch 25/50
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0103 - packet_output_loss: 0.0054 - protocol_output_loss: 0.0021 - temporal_output_loss: 0.0028 - val_loss: 0.0546 - val_packet_output_loss: 0.0030 - val_protocol_output_loss: 0.0491 - val_temporal_output_loss: 0.0028
# Epoch 26/50
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0087 - packet_output_loss: 0.0040 - protocol_output_loss: 0.0019 - temporal_output_loss: 0.0028 - val_loss: 0.0513 - val_packet_output_loss: 0.0032 - val_protocol_output_loss: 0.0442 - val_temporal_output_loss: 0.0042
# Epoch 27/50
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0099 - packet_output_loss: 0.0040 - protocol_output_loss: 0.0022 - temporal_output_loss: 0.0036 - val_loss: 0.0450 - val_packet_output_loss: 0.0028 - val_protocol_output_loss: 0.0403 - val_temporal_output_loss: 0.0022
# Epoch 28/50
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0106 - packet_output_loss: 0.0067 - protocol_output_loss: 0.0018 - temporal_output_loss: 0.0021 - val_loss: 0.0470 - val_packet_output_loss: 0.0031 - val_protocol_output_loss: 0.0422 - val_temporal_output_loss: 0.0020
# Epoch 29/50
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0080 - packet_output_loss: 0.0036 - protocol_output_loss: 0.0019 - temporal_output_loss: 0.0026 - val_loss: 0.0584 - val_packet_output_loss: 0.0087 - val_protocol_output_loss: 0.0439 - val_temporal_output_loss: 0.0061
# Epoch 30/50
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0207 - packet_output_loss: 0.0151 - protocol_output_loss: 0.0024 - temporal_output_loss: 0.0032 - val_loss: 0.0402 - val_packet_output_loss: 0.0035 - val_protocol_output_loss: 0.0345 - val_temporal_output_loss: 0.0025
# Epoch 31/50
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0093 - packet_output_loss: 0.0058 - protocol_output_loss: 0.0018 - temporal_output_loss: 0.0017 - val_loss: 0.0724 - val_packet_output_loss: 0.0289 - val_protocol_output_loss: 0.0409 - val_temporal_output_loss: 0.0029
# Epoch 32/50
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0302 - packet_output_loss: 0.0237 - protocol_output_loss: 0.0022 - temporal_output_loss: 0.0042 - val_loss: 0.0464 - val_packet_output_loss: 0.0030 - val_protocol_output_loss: 0.0375 - val_temporal_output_loss: 0.0062
# Epoch 33/50
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0079 - packet_output_loss: 0.0040 - protocol_output_loss: 0.0015 - temporal_output_loss: 0.0024 - val_loss: 0.0378 - val_packet_output_loss: 0.0035 - val_protocol_output_loss: 0.0314 - val_temporal_output_loss: 0.0031
# Epoch 34/50
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0087 - packet_output_loss: 0.0046 - protocol_output_loss: 0.0014 - temporal_output_loss: 0.0027 - val_loss: 0.0506 - val_packet_output_loss: 0.0061 - val_protocol_output_loss: 0.0357 - val_temporal_output_loss: 0.0090
# Epoch 35/50
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0133 - packet_output_loss: 0.0087 - protocol_output_loss: 0.0018 - temporal_output_loss: 0.0028 - val_loss: 0.0393 - val_packet_output_loss: 0.0041 - val_protocol_output_loss: 0.0329 - val_temporal_output_loss: 0.0025
# Epoch 36/50
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0297 - packet_output_loss: 0.0261 - protocol_output_loss: 0.0016 - temporal_output_loss: 0.0020 - val_loss: 0.0414 - val_packet_output_loss: 0.0032 - val_protocol_output_loss: 0.0356 - val_temporal_output_loss: 0.0029
# Epoch 37/50
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0220 - packet_output_loss: 0.0164 - protocol_output_loss: 0.0019 - temporal_output_loss: 0.0037 - val_loss: 0.0407 - val_packet_output_loss: 0.0029 - val_protocol_output_loss: 0.0348 - val_temporal_output_loss: 0.0033
# Epoch 38/50
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0046 - packet_output_loss: 0.0019 - protocol_output_loss: 0.0012 - temporal_output_loss: 0.0015 - val_loss: 0.0394 - val_packet_output_loss: 0.0022 - val_protocol_output_loss: 0.0349 - val_temporal_output_loss: 0.0026
# Epoch 39/50
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0094 - packet_output_loss: 0.0066 - protocol_output_loss: 0.0012 - temporal_output_loss: 0.0015 - val_loss: 0.0376 - val_packet_output_loss: 0.0025 - val_protocol_output_loss: 0.0321 - val_temporal_output_loss: 0.0033
# Epoch 40/50
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0100 - packet_output_loss: 0.0025 - protocol_output_loss: 0.0013 - temporal_output_loss: 0.0062 - val_loss: 0.0371 - val_packet_output_loss: 0.0029 - val_protocol_output_loss: 0.0315 - val_temporal_output_loss: 0.0029
# Epoch 41/50
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0050 - packet_output_loss: 0.0024 - protocol_output_loss: 0.0013 - temporal_output_loss: 0.0014 - val_loss: 0.0437 - val_packet_output_loss: 0.0050 - val_protocol_output_loss: 0.0361 - val_temporal_output_loss: 0.0029
# Epoch 42/50
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0286 - packet_output_loss: 0.0240 - protocol_output_loss: 0.0030 - temporal_output_loss: 0.0016 - val_loss: 0.0329 - val_packet_output_loss: 0.0027 - val_protocol_output_loss: 0.0271 - val_temporal_output_loss: 0.0033
# Epoch 43/50
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0051 - packet_output_loss: 0.0028 - protocol_output_loss: 0.0012 - temporal_output_loss: 0.0011 - val_loss: 0.0319 - val_packet_output_loss: 0.0024 - val_protocol_output_loss: 0.0261 - val_temporal_output_loss: 0.0036
# Epoch 44/50
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0102 - packet_output_loss: 0.0072 - protocol_output_loss: 0.0012 - temporal_output_loss: 0.0019 - val_loss: 0.0364 - val_packet_output_loss: 0.0091 - val_protocol_output_loss: 0.0253 - val_temporal_output_loss: 0.0022
# Epoch 45/50
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0717 - packet_output_loss: 0.0668 - protocol_output_loss: 0.0019 - temporal_output_loss: 0.0030 - val_loss: 0.0614 - val_packet_output_loss: 0.0045 - val_protocol_output_loss: 0.0538 - val_temporal_output_loss: 0.0035
# Epoch 46/50
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0069 - packet_output_loss: 0.0040 - protocol_output_loss: 0.0014 - temporal_output_loss: 0.0015 - val_loss: 0.0437 - val_packet_output_loss: 0.0116 - val_protocol_output_loss: 0.0283 - val_temporal_output_loss: 0.0041
# Epoch 47/50
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0099 - packet_output_loss: 0.0060 - protocol_output_loss: 0.0014 - temporal_output_loss: 0.0025 - val_loss: 0.0559 - val_packet_output_loss: 0.0237 - val_protocol_output_loss: 0.0279 - val_temporal_output_loss: 0.0045
# Epoch 48/50
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0351 - packet_output_loss: 0.0296 - protocol_output_loss: 0.0027 - temporal_output_loss: 0.0028 - val_loss: 0.0355 - val_packet_output_loss: 0.0029 - val_protocol_output_loss: 0.0299 - val_temporal_output_loss: 0.0029
# Epoch 49/50
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0055 - packet_output_loss: 0.0031 - protocol_output_loss: 0.0012 - temporal_output_loss: 0.0012 - val_loss: 0.0335 - val_packet_output_loss: 0.0031 - val_protocol_output_loss: 0.0274 - val_temporal_output_loss: 0.0032
# Epoch 50/50
# 252/252 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0047 - packet_output_loss: 0.0030 - protocol_output_loss: 9.1459e-04 - temporal_output_loss: 8.4687e-04 - val_loss: 0.0314 - val_packet_output_loss: 0.0031 - val_protocol_output_loss: 0.0261 - val_temporal_output_loss: 0.0024
# WARNING:absl:The `save_format` argument is deprecated in Keras 3. We recommend removing this argument as it can be inferred from the file path. Received: save_format=h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model training completed. Model and scalers saved.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model
import joblib

# Scikit-learn imports for classification and evaluation
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    accuracy_score, 
    precision_score, 
    recall_score, 
    f1_score, 
    confusion_matrix, 
    classification_report,
    ConfusionMatrixDisplay
)

def extract_latent_representations(model_path, data_path, feature_groups):
    """
    Extract latent space representations from the trained autoencoder
    
    Parameters:
    - model_path: Path to the saved autoencoder model
    - data_path: Path to the input data CSV
    - feature_groups: Dictionary of feature groups
    
    Returns:
    - Latent space representations
    - Corresponding labels
    """
    # Load the model
    autoencoder = load_model(model_path, custom_objects={'MeanSquaredError': None})
    
    # Load scalers
    scaler_packet = joblib.load('packet_scaler.pkl')
    scaler_temporal = joblib.load('temporal_scaler.pkl')
    scaler_protocol = joblib.load('protocol_scaler.pkl')
    
    # Load data
    data = pd.read_csv(data_path)
    
    # Separate features
    X_packet = scaler_packet.transform(data[feature_groups['packet_features']])
    X_temporal = scaler_temporal.transform(data[feature_groups['temporal_features']])
    X_protocol = scaler_protocol.transform(data[feature_groups['protocol_features']])
    
    # Extract latent space representations
    encoder = Model(
        inputs=autoencoder.inputs, 
        outputs=autoencoder.get_layer('latent_space').output
    )
    latent_representations = encoder.predict([X_packet, X_temporal, X_protocol])
    
    # Extract labels (assuming the last column is the class label)
    y = data.iloc[:, -1]
    
    return latent_representations, y

def train_random_forest_on_latent_space(latent_reps, labels):
    """
    Train Random Forest Classifier on latent space representations
    
    Parameters:
    - latent_reps: Latent space representations
    - labels: Corresponding class labels
    
    Returns:
    - Trained Random Forest Classifier
    - Train and test sets
    """
    # Split the data
    X_train, X_test, y_train, y_test = train_test_split(
        latent_reps, labels, test_size=0.2, random_state=42
    )
    
    # Train Random Forest Classifier
    rf_classifier = RandomForestClassifier(
        n_estimators=100, 
        random_state=42, 
        n_jobs=-1
    )
    rf_classifier.fit(X_train, y_train)
    
    return rf_classifier, (X_train, X_test, y_train, y_test)

def evaluate_classification_performance(classifier, X_test, y_test):
    """
    Evaluate the performance of the Random Forest Classifier
    
    Parameters:
    - classifier: Trained Random Forest Classifier
    - X_test: Test features
    - y_test: Test labels
    
    Returns:
    - Dictionary of performance metrics
    """
    # Predict on test set
    y_pred = classifier.predict(X_test)
    
    # Calculate metrics
    metrics = {
        'Accuracy': accuracy_score(y_test, y_pred),
        'Precision (Weighted)': precision_score(y_test, y_pred, average='weighted'),
        'Recall (Weighted)': recall_score(y_test, y_pred, average='weighted'),
        'F1 Score (Weighted)': f1_score(y_test, y_pred, average='weighted')
    }
    
    # Print metrics
    print("\nClassification Performance Metrics:")
    for metric, value in metrics.items():
        print(f"{metric}: {value:.4f}")
    
    # Print detailed classification report
    print("\nDetailed Classification Report:")
    print(classification_report(y_test, y_pred))
    
    # Confusion Matrix
    cm = confusion_matrix(y_test, y_pred)
    
    # Plot Confusion Matrix
    plt.figure(figsize=(10, 8))
    ConfusionMatrixDisplay(confusion_matrix=cm).plot(cmap='Blues', values_format='d')
    plt.title('Confusion Matrix for Latent Space Classification')
    plt.tight_layout()
    plt.show()
    plt.close()
    
    return metrics

def main():
    # Define feature groups (adjust according to your dataset)
    feature_groups = {
         'packet_features' : ['ul_total_num_pkts', 'ul_total_num_bytes', 'ul_min_pkt_size', 
                   'ul_max_pkt_size', 'ul_mean_pkt_size', 'ul_std_pkt_size', 
                   'dl_total_num_pkts', 'dl_total_num_bytes', 'dl_min_pkt_size', 
                   'dl_max_pkt_size', 'dl_mean_pkt_size', 'dl_std_pkt_size'],

   
         'temporal_features' : ['ul_min_iat', 'ul_max_iat', 'ul_mean_iat', 'ul_std_iat', 'ul_dur',
                     'dl_min_iat', 'dl_max_iat', 'dl_mean_iat', 'dl_std_iat', 'dl_dur'],

         'protocol_features' : ['protocal', 'port_A', 'port_B','ip_A', 'ip_B']
    }
    
    # Extract latent representations
    latent_representations, labels = extract_latent_representations(
        'multimodal_network_autoencoder.h5', 
        'Processed_random.csv',  # Your input dataset
        feature_groups
    )
    print(latent_representations,labels)
    
    # Train Random Forest on latent space
    rf_classifier, (X_train, X_test, y_train, y_test) = train_random_forest_on_latent_space(
        latent_representations, labels
    )
    
    # Evaluate classification performance
    performance_metrics = evaluate_classification_performance(
        rf_classifier, X_test, y_test
    )
    
    # Optional: Feature importance in the latent space
    plt.figure(figsize=(10, 6))
    feature_importance = rf_classifier.feature_importances_
    plt.bar(range(len(feature_importance)), feature_importance)
    plt.title('Feature Importance in Latent Space')
    plt.xlabel('Latent Dimension')
    plt.ylabel('Importance')
    plt.tight_layout()
    plt.show()
    plt.close()

if __name__ == "__main__":
    main()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# C:\Users\Lenovo\AppData\Roaming\Python\Python311\site-packages\keras\src\models\functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['packet_input', 'temporal_input', 'protocol_input']. Received: the structure of inputs=('*', '*', '*')
#   warnings.warn(
# 314/314 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# [[1.3881112  0.6198651  0.4858622  ... 0.6301744  0.         0.        ]
#  [1.4910495  0.5793471  0.45442307 ... 0.844575   0.         0.        ]
#  [0.7657746  0.44219756 2.4627335  ... 1.7087982  0.3638888  0.        ]
#  ...
#  [1.2212714  3.100498   0.87141657 ... 2.0291955  2.0059977  0.        ]
#  [0.8154648  2.7249577  1.323862   ... 1.3461368  0.5515197  0.        ]
#  [1.2062428  2.7994597  0.5671402  ... 0.8613923  0.         0.        ]] 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 10041    13
# 10042    13
# 10043    13
# 10044    13
# 10045    13
# Name: app, Length: 10046, dtype: int64
#
# Classification Performance Metrics:
# Accuracy: 0.6507
# Precision (Weighted): 0.6465
# Recall (Weighted): 0.6507
# F1 Score (Weighted): 0.6468
#
# Detailed Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.75      0.67      0.70        93
#            1       0.51      0.48      0.49        90
#            2       0.49      0.46      0.47        90
#            3       0.52      0.31      0.39        42
#            4       0.68      0.69      0.69       202
#            5       0.47      0.44      0.45        64
#            6       0.47      0.38      0.42        80
#            7       0.63      0.60      0.62        81
#            8       0.70      0.80      0.75       418
#            9       0.56      0.55      0.55       108
#           10       0.61      0.66      0.63       198
#           11       0.70      0.65      0.67       164
#           12       0.73      0.73      0.73       273
#           13       0.72      0.69      0.70       107
#
#     accuracy                           0.65      2010
#    macro avg       0.61      0.58      0.59      2010
# weighted avg       0.65      0.65      0.65      2010
